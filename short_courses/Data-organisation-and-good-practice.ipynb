# %%
Learning objectives:
- Understand why good data organisation is important
- Learn what best practice is
- Differentiate between good and bad practice


1.	Why are good practices important? It benefits you and others.
- Data is the cornerstone of research
- Good research data management habits are essential to creating data that are suitable for sharing
- Protects from data loss, descruction, or corruption
- Increase research productivity
- Can minimise future work to avoid confusion about what was what
- Enables compliance with ethical codes, data protection laws, journal requirements, and funder/institutional policy
- "Your primary collaborator is you in 6 months, and your past self doesn't answer emails"




% 2.	Labelling variable names and type e.g., string or numeric.
% This seems like an 'inside the data' kind of point, this course is about the data as an object to store??


% 3.	File formats. 
% Same as above - what is the objective of this course?


4.	File naming conventions.
- Where date or version is relevant, use YYYYMMDD or YYYY_MM_DD at the start of a name for easy searching
- No spaces
- No special characters
- Keep names brief but descriptive
- Order name elements from brief to specific
- Use appropriate extensions
- Use meaningful abbreviations

- leading 0's

5.	Include examples of bad filenames and version control asking readers if they can identify the most recent version.

3 versions of the same data: which is clearest



health_dataset, health_cleaned_dataset, health_dataset_filtered
dataset, dataset2, dataset3

Which order are the files? But they're all bad trick question


6.	Include examples of good filenames and highlight good elements.

2025_heart_attack_statistics.csv




7.	README files - what should they contain? Provide examples of good README files.
For a project where data is related, which should be in the same folder, create a README. 
READMEs are a text file (.txt) that contain information. 
- write your README in plain text
- format in an understandable way (use new lines for new information)
- Include important information about each file
    <Filename>.<format> 
    <Dataset unique ID>
    <Date created in YYYYMMDD>
    <file owner> <contact information>
    <Data description> 
    <methodology or scripts used>

    Could also include a changelog to the README

8.	(File permissions – in sharepoint? And Linux?)
