# %% [markdown]
# # Introduction to LLMs Quiz

# %% [markdown]
# The following questions are aimed at testing your understanding of the content that is covered within this course. This course is designed to be accessible to anyone with a basic familiarity with Python, so don't be put off if some of these concepts are new to you — that is exactly what the course is for!
#
# There is no defined threshold below which we believe you should attend the course. Rather, this quiz is aimed at helping you engage with the material and reflect on whether you would benefit from attending. You are encouraged to look things up as you go. Even if you get all the questions right, you are, of course, more than welcome to still attend the course as a refresher!

# %%
from jupyterquiz import display_quiz
display_quiz("quizes/introduction_to_LLMs.json")
# Out:
# <div id="jaSRbOsPsmBO" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #jaSRbOsPsmBO {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# ...
